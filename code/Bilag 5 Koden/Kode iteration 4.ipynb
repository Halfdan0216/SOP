# %%
import numpy as np
import matplotlib.pyplot as plt

height = 12001
width = 12001
r=10
min_step_size=1
max_moves = 100000
greade_tree = 0
greade_move = 0
greade_toofar = 0
stickiness = 0.1

# %%
def point_generator(tree):
    center = np.mean(tree, axis=0)
    distances = np.sqrt(np.sum((tree - center)**2, axis=1))
    max_dist = np.max(distances)

    radius = max_dist * 1.2+10
    angle = np.random.uniform(0, 2*np.pi) 

    y = int(center[0] + radius * np.sin(angle))
    x = int(center[1] + radius * np.cos(angle))

    return np.array([[y, x]])

def point_movement(point, min_step_size, min_distance):
        step_size = max(min_step_size, int(min_distance-(r)) )

        y, x = point[0] 
        angle = np.random.uniform(0, 2 * np.pi)
        dx = round(step_size * np.cos(angle))
        dy = round(step_size * np.sin(angle))
        new_y = y + dy
        new_x = x + dx
        new_point = np.array([[new_y, new_x]])  

        return new_point

def bounce(point, min_step_size, min_distance, tree):
      step_size = max(min_step_size, int(min_distance-(r)) )

      y, x = point[0] 
      angle = np.random.uniform(0, 2 * np.pi)
      dx = round(step_size * np.cos(angle))
      dy = round(step_size * np.sin(angle))
      new_y = y + dy
      new_x = x + dx
      opesite_y = y - dy
      opesite_x = x - dx
      test_point = np.array([[new_y, new_x]]) 
      bounce_point = np.array([[opesite_y, opesite_x]])
      test_distance_to_tree = np.sqrt(np.sum((tree - test_point)**2, axis=1))
      if np.min(test_distance_to_tree) >= min_distance:
         return test_point
      else:
         return bounce_point

# %%
canvas = np.zeros((width,height, 3), dtype=np.uint8)
canvas[:] = [0, 0, 255]

tree = np.array([[height//2, width//2],])
too_far_threshold = 50

new_point = point_generator(tree)

# %%
while len(tree) < (max_moves): 
    distance_to_tree = np.sqrt(np.sum((tree - new_point)**2, axis=1)) 

    if np.any(distance_to_tree <= r ):
        if stickiness >= np.random.uniform(0,1): 
            tree = np.vstack([tree, new_point]) 
            greade_tree += 1

            center = np.mean(tree, axis=0) 
            distances = np.sqrt(np.sum((tree - center) ** 2, axis=1)) 
            max_dist = np.max(distances) 
            too_far_threshold = 40 + max_dist * 1.4
 
            new_point = point_generator(tree)  
        else: 
            greade_move += 1
            new_point = bounce(new_point,min_step_size, np.min(distance_to_tree), tree)
        

    elif np.all(distance_to_tree > too_far_threshold):  
        new_point = point_generator(tree)
        greade_toofar += 1

    else: 
        min_distance = np.min(distance_to_tree)  
        new_point = point_movement(new_point,min_step_size,min_distance) 
        greade_move += 1

# %%
print(greade_tree, greade_move, greade_toofar,len(new_point))

S=0.02

plt.figure(figsize=(S*width/10, S*height/10), dpi=400)
plt.xlim(0, width)
plt.ylim(0, height)
plt.scatter(tree[:, 0], tree[:, 1], s=S, c='red', alpha=1)
plt.gca().set_aspect('equal')
plt.axis('off')
plt.show()
# Out:
# 99999 7997903 49874 1
